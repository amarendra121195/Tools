# %%
import os
# here add open api keys

# %%
# !pip install -q langchain-openai langchain-community langchain-core requests duckduckgo-search
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-experimental 0.3.4 requires langchain-core<0.4.0,>=0.3.28, but you have langchain-core 1.0.5 which is incompatible.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
import requests

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

# %%
@tool
def get_weather_data(city: str) -> str:
  """
  This function fetches the current weather data for a given city
  """
  url = f'https://api.weatherstack.com/current?access_key=4d1d8ae207a8c845a52df8a67bf3623e&query={city}'

  response = requests.get(url)

  return response.json()

# %%
llm = ChatOpenAI()

# %%
pip install -U langchain langchain-core langchain-community langchain-openai
# Out:
# Requirement already satisfied: langchain in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (1.0.7)
# Requirement already satisfied: langchain-core in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (1.0.5)
# Requirement already satisfied: langchain-community in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-openai in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (1.0.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain) (2.11.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-core) (0.4.23)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-core) (4.13.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (2.0.40)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-openai) (2.8.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.10.16)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.14.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U langchain langchain-community langchain-core langchain-openai
# Out:
# Requirement already satisfied: langchain in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (1.0.7)
# Requirement already satisfied: langchain-community in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (1.0.5)
# Requirement already satisfied: langchain-openai in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (1.0.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (0.4.43)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-community) (2.3.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-openai) (2.8.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.agents import create_react_agent, AgentExecutor
from langchain import hub
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 from langchain.agents import create_react_agent, AgentExecutor
#       2 from langchain import hub
#
# ImportError: cannot import name 'create_react_agent' from 'langchain.agents' (c:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\langchain\agents\__init__.py)

# %%
# Step 2: Pull the ReAct prompt from LangChain Hub
from langchain import hub
prompt = hub.pull("hwchase17/react")  # pulls the standard ReAct agent prompt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Step 2: Pull the ReAct prompt from LangChain Hub
# ----> 2 from langchain import hub
#       3 prompt = hub.pull("hwchase17/react")  # pulls the standard ReAct agent prompt
#
# ImportError: cannot import name 'hub' from 'langchain' (c:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\langchain\__init__.py)

# %%
# Step 3: Create the ReAct agent manually with the pulled prompt
agent = create_react_agent(
    llm=llm,
    tools=[search_tool, get_weather_data],
    prompt=prompt
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Step 3: Create the ReAct agent manually with the pulled prompt
# ----> 2 agent = create_react_agent(
#       3     llm=llm,
#       4     tools=[search_tool, get_weather_data],
#       5     prompt=prompt
#       6 )
#
# NameError: name 'create_react_agent' is not defined

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.0.5

# %%
# Step 4: Wrap it with AgentExecutor
agent_executor = AgentExecutor(
    agent=agent,
    tools=[search_tool, get_weather_data],
    verbose=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Step 4: Wrap it with AgentExecutor
# ----> 2 agent_executor = AgentExecutor(
#       3     agent=agent,
#       4     tools=[search_tool, get_weather_data],
#       5     verbose=True
#       6 )
#
# NameError: name 'AgentExecutor' is not defined

# %%
pip install --upgrade --force-reinstall --no-cache-dir langchain langchain-community langchain-core langgraph
# Out:
# Collecting langchain
#   Downloading langchain-1.0.7-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core
#   Downloading langchain_core-1.0.5-py3-none-any.whl.metadata (3.6 kB)
# Collecting langgraph
#   Downloading langgraph-1.0.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Downloading sqlalchemy-2.0.44-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting PyYAML<7.0.0,>=5.3.0 (from langchain-community)
#   Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.13.2-cp311-cp311-win_amd64.whl.metadata (8.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-community)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langsmith<1.0.0,>=0.1.125 (from langchain-community)
#   Downloading langsmith-0.4.43-py3-none-any.whl.metadata (14 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting numpy>=1.26.2 (from langchain-community)
#   Downloading numpy-2.3.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging<26.0.0,>=23.2.0 (from langchain-core)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph)
#   Downloading langgraph_prebuilt-1.0.4-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.8.0-cp311-cp311-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.7.0-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.4.1-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.22.0-cp311-cp311-win_amd64.whl.metadata (77 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.0.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.12.0-cp311-cp311-win_amd64.whl.metadata (1.2 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Downloading orjson-3.11.4-cp311-cp311-win_amd64.whl.metadata (42 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.32.5->langchain-community)
#   Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.32.5->langchain-community)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.32.5->langchain-community)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.32.5->langchain-community)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community)
#   Downloading greenlet-3.2.4-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Collecting anyio (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Downloading anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting sniffio>=1.1 (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Downloading langchain-1.0.7-py3-none-any.whl (93 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 699.0 kB/s eta 0:00:03
#    ------------ --------------------------- 0.8/2.5 MB 958.5 kB/s eta 0:00:02
#    ------------ --------------------------- 0.8/2.5 MB 958.5 kB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.5 MB 824.4 kB/s eta 0:00:02
#    ------------------------ --------------- 1.6/2.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.5 MB 1.1 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.2 MB/s eta 0:00:00
# Downloading langchain_core-1.0.5-py3-none-any.whl (471 kB)
# Downloading langgraph-1.0.3-py3-none-any.whl (156 kB)
# Downloading aiohttp-3.13.2-cp311-cp311-win_amd64.whl (456 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.9 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Downloading langgraph_prebuilt-1.0.4-py3-none-any.whl (34 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading langsmith-0.4.43-py3-none-any.whl (410 kB)
# Downloading numpy-2.3.4-cp311-cp311-win_amd64.whl (13.1 MB)
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.1 MB 1.2 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/13.1 MB 1.2 MB/s eta 0:00:11
#    -- ------------------------------------- 0.8/13.1 MB 1.0 MB/s eta 0:00:13
#    ---- ----------------------------------- 1.3/13.1 MB 1.2 MB/s eta 0:00:10
#    ---- ----------------------------------- 1.6/13.1 MB 1.3 MB/s eta 0:00:09
#    ------ --------------------------------- 2.1/13.1 MB 1.4 MB/s eta 0:00:08
#    ------- -------------------------------- 2.4/13.1 MB 1.5 MB/s eta 0:00:08
#    -------- ------------------------------- 2.9/13.1 MB 1.6 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.4/13.1 MB 1.7 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.7/13.1 MB 1.7 MB/s eta 0:00:06
#    ------------ --------------------------- 4.2/13.1 MB 1.7 MB/s eta 0:00:06
#    ------------- -------------------------- 4.5/13.1 MB 1.6 MB/s eta 0:00:06
#    ------------- -------------------------- 4.5/13.1 MB 1.6 MB/s eta 0:00:06
#    -------------- ------------------------- 4.7/13.1 MB 1.6 MB/s eta 0:00:06
#    --------------- ------------------------ 5.0/13.1 MB 1.6 MB/s eta 0:00:06
#    ---------------- ----------------------- 5.2/13.1 MB 1.5 MB/s eta 0:00:06
#    ----------------- ---------------------- 5.8/13.1 MB 1.5 MB/s eta 0:00:05
#    ------------------ --------------------- 6.0/13.1 MB 1.5 MB/s eta 0:00:05
#    -------------------- ------------------- 6.6/13.1 MB 1.6 MB/s eta 0:00:05
#    --------------------- ------------------ 7.1/13.1 MB 1.6 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.3/13.1 MB 1.6 MB/s eta 0:00:04
#    ------------------------ --------------- 7.9/13.1 MB 1.6 MB/s eta 0:00:04
#    ------------------------ --------------- 8.1/13.1 MB 1.7 MB/s eta 0:00:03
#    ------------------------- -------------- 8.4/13.1 MB 1.7 MB/s eta 0:00:03
#    --------------------------- ------------ 8.9/13.1 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.4/13.1 MB 1.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.7/13.1 MB 1.7 MB/s eta 0:00:02
#    ------------------------------- -------- 10.2/13.1 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 10.5/13.1 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 10.7/13.1 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.3/13.1 MB 1.7 MB/s eta 0:00:02
#    ------------------------------------ --- 11.8/13.1 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 12.1/13.1 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 12.3/13.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  12.8/13.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 13.1/13.1 MB 1.7 MB/s eta 0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 2.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.7 MB/s eta 0:00:00
# Downloading pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading sqlalchemy-2.0.44-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 2.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 1.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.8 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl (31 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-win_amd64.whl (44 kB)
# Downloading greenlet-3.2.4-cp311-cp311-win_amd64.whl (299 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.0-cp311-cp311-win_amd64.whl (46 kB)
# Downloading orjson-3.11.4-cp311-cp311-win_amd64.whl (131 kB)
# Downloading ormsgpack-1.12.0-cp311-cp311-win_amd64.whl (112 kB)
# Downloading propcache-0.4.1-cp311-cp311-win_amd64.whl (41 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading yarl-1.22.0-cp311-cp311-win_amd64.whl (86 kB)
# Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, xxhash, urllib3, typing-extensions, tenacity, sniffio, PyYAML, python-dotenv, propcache, packaging, ormsgpack, orjson, numpy, mypy-extensions, multidict, jsonpointer, idna, httpx-sse, h11, greenlet, frozenlist, charset_normalizer, certifi, attrs, annotated-types, aiohappyeyeballs, yarl, typing-inspection, typing-inspect, SQLAlchemy, requests, pydantic-core, marshmallow, jsonpatch, httpcore, anyio, aiosignal, requests-toolbelt, pydantic, httpx, dataclasses-json, aiohttp, pydantic-settings, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langchain-text-splitters, langgraph-prebuilt, langchain-classic, langgraph, langchain-community, langchain
#   Attempting uninstall: zstandard
#     Found existing installation: zstandard 0.23.0
#     Uninstalling zstandard-0.23.0:
#       Successfully uninstalled zstandard-0.23.0
#   Attempting uninstall: xxhash
#     Found existing installation: xxhash 3.6.0
#     Uninstalling xxhash-3.6.0:
#       Successfully uninstalled xxhash-3.6.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.13.2
#     Uninstalling typing_extensions-4.13.2:
#       Successfully uninstalled typing_extensions-4.13.2
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.1.2
#     Uninstalling tenacity-9.1.2:
#       Successfully uninstalled tenacity-9.1.2
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.1
#     Uninstalling sniffio-1.3.1:
#       Successfully uninstalled sniffio-1.3.1
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.1.1
#     Uninstalling python-dotenv-1.1.1:
#       Successfully uninstalled python-dotenv-1.1.1
#   Attempting uninstall: propcache
#     Found existing installation: propcache 0.3.2
#     Uninstalling propcache-0.3.2:
#       Successfully uninstalled propcache-0.3.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: ormsgpack
#     Found existing installation: ormsgpack 1.12.0
#     Uninstalling ormsgpack-1.12.0:
#       Successfully uninstalled ormsgpack-1.12.0
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.10.16
#     Uninstalling orjson-3.10.16:
#       Successfully uninstalled orjson-3.10.16
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
#   Attempting uninstall: mypy-extensions
#     Found existing installation: mypy_extensions 1.1.0
#     Uninstalling mypy_extensions-1.1.0:
#       Successfully uninstalled mypy_extensions-1.1.0
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.6.4
#     Uninstalling multidict-6.6.4:
#       Successfully uninstalled multidict-6.6.4
#   Attempting uninstall: jsonpointer
#     Found existing installation: jsonpointer 3.0.0
#     Uninstalling jsonpointer-3.0.0:
#       Successfully uninstalled jsonpointer-3.0.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: httpx-sse
#     Found existing installation: httpx-sse 0.4.1
#     Uninstalling httpx-sse-0.4.1:
#       Successfully uninstalled httpx-sse-0.4.1
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.2.1
#     Uninstalling greenlet-3.2.1:
#       Successfully uninstalled greenlet-3.2.1
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.7.0
#     Uninstalling frozenlist-1.7.0:
#       Successfully uninstalled frozenlist-1.7.0
#   Attempting uninstall: charset_normalizer
#     Found existing installation: charset-normalizer 3.4.1
#     Uninstalling charset-normalizer-3.4.1:
#       Successfully uninstalled charset-normalizer-3.4.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.1.31
#     Uninstalling certifi-2025.1.31:
#       Successfully uninstalled certifi-2025.1.31
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.3.0
#     Uninstalling attrs-25.3.0:
#       Successfully uninstalled attrs-25.3.0
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.7.0
#     Uninstalling annotated-types-0.7.0:
#       Successfully uninstalled annotated-types-0.7.0
#   Attempting uninstall: aiohappyeyeballs
#     Found existing installation: aiohappyeyeballs 2.6.1
#     Uninstalling aiohappyeyeballs-2.6.1:
#       Successfully uninstalled aiohappyeyeballs-2.6.1
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.20.1
#     Uninstalling yarl-1.20.1:
#       Successfully uninstalled yarl-1.20.1
#   Attempting uninstall: typing-inspection
#     Found existing installation: typing-inspection 0.4.0
#     Uninstalling typing-inspection-0.4.0:
#       Successfully uninstalled typing-inspection-0.4.0
#   Attempting uninstall: typing-inspect
#     Found existing installation: typing-inspect 0.9.0
#     Uninstalling typing-inspect-0.9.0:
#       Successfully uninstalled typing-inspect-0.9.0
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.40
#     Uninstalling SQLAlchemy-2.0.40:
#       Successfully uninstalled SQLAlchemy-2.0.40
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.5
#     Uninstalling requests-2.32.5:
#       Successfully uninstalled requests-2.32.5
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.1
#     Uninstalling pydantic_core-2.33.1:
#       Successfully uninstalled pydantic_core-2.33.1
#   Attempting uninstall: marshmallow
#     Found existing installation: marshmallow 3.26.1
#     Uninstalling marshmallow-3.26.1:
#       Successfully uninstalled marshmallow-3.26.1
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.33
#     Uninstalling jsonpatch-1.33:
#       Successfully uninstalled jsonpatch-1.33
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.8
#     Uninstalling httpcore-1.0.8:
#       Successfully uninstalled httpcore-1.0.8
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.9.0
#     Uninstalling anyio-4.9.0:
#       Successfully uninstalled anyio-4.9.0
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.4.0
#     Uninstalling aiosignal-1.4.0:
#       Successfully uninstalled aiosignal-1.4.0
#   Attempting uninstall: requests-toolbelt
#     Found existing installation: requests-toolbelt 1.0.0
#     Uninstalling requests-toolbelt-1.0.0:
#       Successfully uninstalled requests-toolbelt-1.0.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.3
#     Uninstalling pydantic-2.11.3:
#       Successfully uninstalled pydantic-2.11.3
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: dataclasses-json
#     Found existing installation: dataclasses-json 0.6.7
#     Uninstalling dataclasses-json-0.6.7:
#       Successfully uninstalled dataclasses-json-0.6.7
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.12.15
#     Uninstalling aiohttp-3.12.15:
#       Successfully uninstalled aiohttp-3.12.15
#   Attempting uninstall: pydantic-settings
#     Found existing installation: pydantic-settings 2.10.1
#     Uninstalling pydantic-settings-2.10.1:
#       Successfully uninstalled pydantic-settings-2.10.1
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.4.23
#     Uninstalling langsmith-0.4.23:
#       Successfully uninstalled langsmith-0.4.23
#   Attempting uninstall: langgraph-sdk
#     Found existing installation: langgraph-sdk 0.2.9
#     Uninstalling langgraph-sdk-0.2.9:
#       Successfully uninstalled langgraph-sdk-0.2.9
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.0.5
#     Uninstalling langchain-core-1.0.5:
#       Successfully uninstalled langchain-core-1.0.5
#   Attempting uninstall: langgraph-checkpoint
#     Found existing installation: langgraph-checkpoint 3.0.1
#     Uninstalling langgraph-checkpoint-3.0.1:
#       Successfully uninstalled langgraph-checkpoint-3.0.1
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 1.0.0
#     Uninstalling langchain-text-splitters-1.0.0:
#       Successfully uninstalled langchain-text-splitters-1.0.0
#   Attempting uninstall: langgraph-prebuilt
#     Found existing installation: langgraph-prebuilt 1.0.4
#     Uninstalling langgraph-prebuilt-1.0.4:
#       Successfully uninstalled langgraph-prebuilt-1.0.4
#   Attempting uninstall: langchain-classic
#     Found existing installation: langchain-classic 1.0.0
#     Uninstalling langchain-classic-1.0.0:
#       Successfully uninstalled langchain-classic-1.0.0
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.0.3
#     Uninstalling langgraph-1.0.3:
#       Successfully uninstalled langgraph-1.0.3
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.4.1
#     Uninstalling langchain-community-0.4.1:
#       Successfully uninstalled langchain-community-0.4.1
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.0.7
#     Uninstalling langchain-1.0.7:
#       Successfully uninstalled langchain-1.0.7
# Successfully installed PyYAML-6.0.3 SQLAlchemy-2.0.44 aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 annotated-types-0.7.0 anyio-4.11.0 attrs-25.4.0 certifi-2025.11.12 charset_normalizer-3.4.4 dataclasses-json-0.6.7 frozenlist-1.8.0 greenlet-3.2.4 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 httpx-sse-0.4.3 idna-3.11 jsonpatch-1.33 jsonpointer-3.0.0 langchain-1.0.7 langchain-classic-1.0.0 langchain-community-0.4.1 langchain-core-1.0.5 langchain-text-splitters-1.0.0 langgraph-1.0.3 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.4 langgraph-sdk-0.2.9 langsmith-0.4.43 marshmallow-3.26.1 multidict-6.7.0 mypy-extensions-1.1.0 numpy-2.3.4 orjson-3.11.4 ormsgpack-1.12.0 packaging-25.0 propcache-0.4.1 pydantic-2.12.4 pydantic-core-2.41.5 pydantic-settings-2.12.0 python-dotenv-1.2.1 requests-2.32.5 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 typing-extensions-4.15.0 typing-inspect-0.9.0 typing-inspection-0.4.2 urllib3-2.5.0 xxhash-3.6.0 yarl-1.22.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\~standard'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\~xhash'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\~aml'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\~rmsgpack'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\~rjson'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\~harset_normalizer'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\~ydantic_core'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-experimental 0.3.4 requires langchain-community<0.4.0,>=0.3.0, but you have langchain-community 0.4.1 which is incompatible.
# langchain-experimental 0.3.4 requires langchain-core<0.4.0,>=0.3.28, but you have langchain-core 1.0.5 which is incompatible.
# langchain-groq 0.3.7 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.5 which is incompatible.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.5.2 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.4 which is incompatible.

# %%
# Step 5: Invoke
response = agent_executor.invoke({"input": "Find the capital of Madhya Pradesh, then find it's current weather condition"})
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Step 5: Invoke
# ----> 2 response = agent_executor.invoke({"input": "Find the capital of Madhya Pradesh, then find it's current weather condition"})
#       3 print(response)
#
# NameError: name 'agent_executor' is not defined

# %%
from langchain_openai import ChatOpenAI
from langchain.tools import tool
from langgraph.prebuilt import create_react_agent

# %%
from langchain_openai import ChatOpenAI
from langchain.tools import tool
from langgraph.prebuilt import create_react_agent

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",   # or gpt-4o, gpt-4.1, etc.
    temperature=0
)

# %%
agent_executor = create_react_agent(
    llm,
    tools=[add_numbers, multiply_numbers]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 agent_executor = create_react_agent(
#       2     llm,
# ----> 3     tools=[add_numbers, multiply_numbers]
#       4 )
#
# NameError: name 'add_numbers' is not defined

# %%
# Step 5: Invoke
response = agent_executor.invoke({"input": "Find the capital of Madhya Pradesh, then find it's current weather condition"})
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 # Step 5: Invoke
# ----> 2 response = agent_executor.invoke({"input": "Find the capital of Madhya Pradesh, then find it's current weather condition"})
#       3 print(response)
#
# NameError: name 'agent_executor' is not defined

# %%
response['output']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 response['output']
#
# NameError: name 'response' is not defined
